# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep

service = Service(ChromeDriverManager().install())
nav = webdriver.Chrome(service=service)

# %%
import os

caminho = 'file://' + os.getcwd() 
print(caminho)
archive = caminho + 'paginas/index_processo.html'
print(archive)
nav.get(archive)
# Out:
# file:///home/usuario/Documentos/Repositorys/NotaWeb/NotaWeb/JusSearch
# file:///home/usuario/Documentos/Repositorys/NotaWeb/NotaWeb/JusSearchpaginas/index_processo.html

# %%
import pandas as pd
import os

caminho_arquivo = os.path.join(os.getcwd(), 'data')
processos = pd.read_excel(caminho_arquivo + '/Processos.xlsx')
processos.info()
processos['Status'] = processos['Status'].astype(str)
display(processos)

df_nome = processos['Nome'][0]
df_advogado = processos['Advogado'][0]
df_processo = processos['Processo'][0]
df_cidade = processos['Cidade'][0]
df_status = processos['Status'][0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      4 non-null      object
#  1   Advogado  4 non-null      object
#  2   Processo  4 non-null      object
#  3   Cidade    4 non-null      object
#  4   Status    0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 292.0+ bytes
#      Nome      Advogado Processo            Cidade Status
# 0    Lira   Alon Lawyer   PC6592  Distrito Federal    nan
# 1    João   Lawyer Alon   EB3792    Rio de Janeiro    nan
# 2  Amanda  Amanda mesmo   MM1043    Rio de Janeiro    nan
# 3   Carol        Amanda   PC5197         São Paulo    nan

# %%
from selenium.webdriver import ActionChains

# Para cada processo
nav.get(archive)

for linha in processos.index:

    cidade = processos.loc[linha, 'Cidade']        
    sleep(1)
    escolha_estado = nav.find_element(By.CLASS_NAME, 'dropdown-menu')
    ActionChains(nav).move_to_element(escolha_estado).perform()


    sleep(1)
    nav.find_element(By.PARTIAL_LINK_TEXT, cidade).click()

    # Abas 
    index_aba = nav.window_handles[0]

    registro_aba = nav.window_handles[1]

    nav.switch_to.window(registro_aba)

    nome_da_parte = nav.find_element(By.ID, 'nome').send_keys(processos.loc[linha, "Nome"])
    advogado = nav.find_element(By.ID, 'advogado').send_keys(processos.loc[linha, 'Advogado'])
    num_processo = nav.find_element(By.ID, 'numero').send_keys(processos.loc[linha, 'Processo'])
    

    pesquisar = nav.find_element(By.CLASS_NAME, 'registerbtn')
    sleep(0.3)
    pesquisar.click()

    alerta = nav.switch_to.alert
    mensagem_alerta = alerta.text
    print(mensagem_alerta)
    alerta.accept()

    while True:
        try:
            alerta = nav.switch_to.alert
            break
        except:
            sleep(1)
    print(mensagem_alerta)
        
    if 'Processo encontrado com sucesso' in mensagem_alerta:
        sleep(2)
        print('Processo encontrado com sucesso!')
        alerta.accept()
        processos.loc[linha, 'Status'] = 'Encontrado'
        print('accept')
        alerta.accept()
        nav.close()
    else:
        sleep(2)
        processos.loc[linha, 'Status'] = 'Não encontrado'
        alerta.accept()
        nav.close()
    sleep(1)

    nav.switch_to.window(index_aba)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 10
#       8 cidade = processos.loc[linha, 'Cidade']
#       9 sleep(1)
# ---> 10 escolha_estado = nav.find_element(By.CLASS_NAME, 'dropdown-menu')
#      11 ActionChains(nav).move_to_element(escolha_estado).perform()
#      14 sleep(1)
#
# File ~/Documentos/Repositorys/NotaWeb/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/Documentos/Repositorys/NotaWeb/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~/Documentos/Repositorys/NotaWeb/.conda/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-menu"}
#   (Session info: chrome=131.0.6778.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x55900ff3831a <unknown>
# #1 0x55900fa4e6e0 <unknown>
# #2 0x55900fa9d3e6 <unknown>
# #3 0x55900fa9d681 <unknown>
# #4 0x55900fae2b04 <unknown>
# #5 0x55900fac148d <unknown>
# #6 0x55900fadfed7 <unknown>
# #7 0x55900fac1203 <unknown>
# #8 0x55900fa8fcc0 <unknown>
# #9 0x55900fa90c9e <unknown>
# #10 0x55900ff05d0b <unknown>
# #11 0x55900ff09c92 <unknown>
# #12 0x55900fef2b3c <unknown>
# #13 0x55900ff0a807 <unknown>
# #14 0x55900fed80df <unknown>
# #15 0x55900ff27578 <unknown>
# #16 0x55900ff27740 <unknown>
# #17 0x55900ff37196 <unknown>
# #18 0x7fcce0b26ea7 start_thread

# %%
display(processos)
processos.info()
# Out:
#      Nome      Advogado Processo            Cidade          Status
# 0    Lira   Alon Lawyer   PC6592  Distrito Federal  Não encontrado
# 1    João   Lawyer Alon   EB3792    Rio de Janeiro  Não encontrado
# 2  Amanda  Amanda mesmo   MM1043    Rio de Janeiro  Não encontrado
# 3   Carol        Amanda   PC5197         São Paulo  Não encontrado
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      4 non-null      object
#  1   Advogado  4 non-null      object
#  2   Processo  4 non-null      object
#  3   Cidade    4 non-null      object
#  4   Status    4 non-null      object
# dtypes: object(5)
# memory usage: 292.0+ bytes
